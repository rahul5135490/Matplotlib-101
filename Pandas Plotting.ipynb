# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\rcmlp.12\\Desktop\\working file\\New data\\232704_risk.csv")

# %%
df
# Out:
#    DATE_OF_REMOVAL AIRCRAFT  PART_REMOVED SN_REMOVED PART_POSITION  \
# 0        03-Jan-14   N451PA  822-1239-101     133551          ONLY
# 1        07-Sep-14   N450PA  822-1239-101     133560          ONLY
# 2        27-Nov-15   N450PA  822-1239-101     133551          ONLY
# 3        01-Feb-16   N454PA  822-1239-101     133565          ONLY
# 4        02-Apr-16   N857GT  822-1239-151     17R4DH          ONLY
# 5        18-Jun-16   N857GT  822-1239-151     18Y6RL          ONLY
# 6        25-Jun-16   N857GT  822-1239-151     40956H          ONLY
# 7        03-Oct-16   N852GT  822-1239-151     18Y893          ONLY
# 8        18-Nov-16   N407KZ  822-1239-151     1737MP          ONLY
# 9        07-Mar-17   N407KZ  822-1239-151     17R4DH          ONLY
# 10       26-Mar-17   N856GT  822-1239-151     18C4TR          ONLY
# 11       28-May-17   N451PA  822-1239-101     142608          ONLY
# 12       20-Jun-17   N454PA  822-1239-101     133551          ONLY
# 13       19-Jul-17   N856GT  822-1239-151     18Y8TY          ONLY
# 14       26-Nov-17   N404KZ  822-1239-151     17F7KG          ONLY
# 15       10-Dec-17   N450PA  822-1239-101     133528          ONLY
# 16       15-Dec-17   N450PA  822-1239-101     142608          ONLY
# 17       25-Jan-18   N407KZ  822-1239-151     1737MP          ONLY
# 18       08-Jun-18   N454PA  822-1239-101     133560          ONLY
# 19       10-Jun-18   N454PA  822-1239-101     142608          ONLY
# 20       25-Sep-18   N404KZ  822-1239-151     18TGM6          ONLY
# 21       12-Nov-18   N404KZ  822-1239-151     1737MP          ONLY
# 22       28-Jan-19   N851GT  822-1239-151     18HC9K          ONLY
# 23       11-Apr-19   N854GT  822-1239-151     18Y6RL          ONLY
# 24       21-May-19   N854GT  822-1239-151     18Y893          ONLY
# 25       26-May-19   N452PA  822-1239-101     132032          ONLY
# 26       30-May-19   N407KZ  822-1239-151     17CLMR          ONLY
# 27       12-Jul-19   N451PA  822-1239-101     133565          ONLY
# 28       21-Jan-20   N855GT  822-1239-151     41GXFY          ONLY
# 29       23-Jul-20   N450PA  822-1239-101     133551          ONLY
# 30       28-Jul-20   N450PA  822-1239-101     133565          ONLY
# 31       08-Jan-21   N856GT  822-1239-151     18Y8T1          ONLY
# 32       13-Feb-21   N451PA  822-1239-101     132032          ONLY
# 33       20-Feb-21   N451PA  822-1239-101     133565          ONLY
# 34       09-May-21   N454PA  822-1239-101     133528          ONLY
# 35       26-May-21   N857GT  822-1239-151     18HC9H          ONLY
#
#     TIME_SINCE_INSTALL  FAILURE PROBABILITY @85%  FAILURE PROBABILITY @95%  \
# 0              16662.0                     22640                     32785
# 1               5005.0                     22640                     32785
# 2               4743.0                     22640                     32785
# 3               8530.0                     22640                     32785
# 4              18109.0                     22640                     32785
# 5                984.0                     22640                     32785
# 6                 90.0                     22640                     32785
# 7               1505.0                     22640                     32785
# 8              30595.0                     22640                     32785
# 9               1218.0                     22640                     32785
# 10             22881.0                     22640                     32785
# 11             13285.0                     22640                     32785
# 12              5545.0                     22640                     32785
# 13              1247.0                     22640                     32785
# 14             38344.0                     22640                     32785
# 15              7351.0                     22640                     32785
# 16                82.0                     22640                     32785
# 17              4125.0                     22640                     32785
# 18              3642.0                     22640                     32785
# 19                25.0                     22640                     32785
# 20              3600.0                     22640                     32785
# 21               618.0                     22640                     32785
# 22             27729.0                     22640                     32785
# 23              9608.0                     22640                     32785
# 24               395.0                     22640                     32785
# 25             24941.0                     22640                     32785
# 26              5385.0                     22640                     32785
# 27              8016.0                     22640                     32785
# 28             22452.0                     22640                     32785
# 29              9594.0                     22640                     32785
# 30                39.0                     22640                     32785
# 31             14376.0                     22640                     32785
# 32              6302.0                     22640                     32785
# 33                85.0                     22640                     32785
# 34             11252.0                     22640                     32785
# 35             22200.0                     22640                     32785
#
#                                        REMOVAL_REASON REMOVAL_TYPE
# 0   COULD NOT UPLOAD FLIGHT PLAN OR WINDS ALOFT ON...            U
# 1                      REFF MDDR # 51094. ACARS INOP.            U
# 2   CANNOT RECEIVE FLIGHT PLAN OR WINDS VIA ACARSO...            U
# 3   AIRCRAFT LOG PG 704428 ITEM 1 - VHF DATA APPEA...            U
# 4   MDDR 65428 - CAN'T GET FLIGHT PLAN OR WINDS FR...            U
# 5           UNABLE TO GET ATIS OR CLEARANCE ON ACARS.            U
# 6               REF MDDR 67803ATIS INOP THROUGH ACARS            U
# 7                   REF ACTION PLAN 12216 RPL THE CMU            U
# 8   FOUND ACARS CMU FAIL MSG 23304RMV PN:822-1239-...            U
# 9   REF DMI #75603 ACARS WIND & FLT PLAN WILL NOT ...            U
# 10  MEL - MDDR 76161 - ACARS INOPERATIVE. ( AIRCRA...            U
# 11  REF MDDR 78544 ACARS INOP NO DOWNLOAD FOR ATIX...            U
# 12                          REF MDDR 79441 ACARS INOP            U
# 13  MDDR # 80544 ACARS UNABLE TO RECEIVE ATIS FROM...            U
# 14  REF MDDR # 86378. ON P/N: 822-1239-151, S/N: 1...            U
# 15               CANNOT RECEIVE ATIS OR WX VIA ACARS.            U
# 16      NO CORRECT INFO FROM CMU NO REQUESTS IN ACARS            U
# 17                     acars application menu aoc err            U
# 18  TO BE ACCOMPLISHED AP-14209 ACARS SYSTEM INOP....            U
# 19            (REF WO 37774)(MDDR #94893) ACARS INOP.            U
# 20                  REF MDDR # 100031. ( CPDLC INOP )            U
# 21                        ACARS SYSTEM IS INOPERATIVE            U
# 22                          REF MDDR 106488ACARS INOP            U
# 23                                                NaN            U
# 24  REF ACTION PLAN 15319 RPL THE CMU AND REC SOFT...            U
# 25  AFTER TAKEOFF ACARS STARTED TO INTERMITTENTLY ...            U
# 26                                 REF MDDR # 112370.            U
# 27  STATUS ACARS MU . P/N OFF 822-1239-101 S/N OFF...            U
# 28                                    REF DMI #123593            U
# 29  IN FLT ACARS DATA DUMPED INIT DATA AND FLT LOG...            U
# 30                           ACARS INOP (STK-NR-0004)            U
# 31                          CMU FAIL (NO BUS OUTPUTS)            U
# 32                     ACARS MU FAIL (NO BUS OUTPUTS)            U
# 33  TO BE PERFORMED W/O 77412. AP- 19085 ACARS MU ...            U
# 34  PER CUSTOMER REQUEST: REMOVE RIGHT CMU AND PLA...            U
# 35                       REF MDDR 147268 SELCAL INOP.            U

# %%
df.plot()

plt.show()

# %%
# Scatter Plot-Specify that you want a scatter plot with the kind argument:-kind = 'scatter'- A scatter plot needs an x- and a y-axis.-In the example below we will use "Duration" for the x-axis and "Calories" for the y-axis.-Include the x and y arguments like this:-x = 'Duration', y = 'Calories'-Example

# %%
df.head()
# Out:
#   DATE_OF_REMOVAL AIRCRAFT  PART_REMOVED SN_REMOVED PART_POSITION  \
# 0       03-Jan-14   N451PA  822-1239-101     133551          ONLY
# 1       07-Sep-14   N450PA  822-1239-101     133560          ONLY
# 2       27-Nov-15   N450PA  822-1239-101     133551          ONLY
# 3       01-Feb-16   N454PA  822-1239-101     133565          ONLY
# 4       02-Apr-16   N857GT  822-1239-151     17R4DH          ONLY
#
#    TIME_SINCE_INSTALL  FAILURE PROBABILITY @85%  FAILURE PROBABILITY @95%  \
# 0             16662.0                     22640                     32785
# 1              5005.0                     22640                     32785
# 2              4743.0                     22640                     32785
# 3              8530.0                     22640                     32785
# 4             18109.0                     22640                     32785
#
#                                       REMOVAL_REASON REMOVAL_TYPE
# 0  COULD NOT UPLOAD FLIGHT PLAN OR WINDS ALOFT ON...            U
# 1                     REFF MDDR # 51094. ACARS INOP.            U
# 2  CANNOT RECEIVE FLIGHT PLAN OR WINDS VIA ACARSO...            U
# 3  AIRCRAFT LOG PG 704428 ITEM 1 - VHF DATA APPEA...            U
# 4  MDDR 65428 - CAN'T GET FLIGHT PLAN OR WINDS FR...            U

# %%
df.plot(kind = 'scatter', x = 'AIRCRAFT', y = 'FAILURE PROBABILITY @95%')

plt.show()

# %%
df["TIME_SINCE_INSTALL"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
